# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from PIL import Image
from torchvision import models, transforms
from torchvision.transforms.functional import InterpolationMode

import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# DATA_ROOT = Path(r"/home/sergiocloudwork/dataset/sampled_500/val")
DATA_ROOT = Path(r"D:/dataset/sampled_500/val")
# number of image
z=10

# %%
loc = Path.cwd()
imgNetF = loc / "resNet_data"


pth_file=[]
# Find and read all JSON files recursively
for file_path in imgNetF.rglob("*.pth"):
    print(f"Found: {file_path}")
    pth_file.append(file_path)


model_name={"inat_resnet18_500_ptclasses_imagenet.pth":"ResNet18 pretrained model",
            "inat_resnet50_500_ptclasses_imagenet.pth":"ResNet50 pretrained model",
            "inat_resnet18_500_npclasses_imagenet.pth":"ResNet18 random start model",
            "inat_resnet50_500_npclasses_imagenet.pth":"ResNet50 random start model",
            }


print(len(model_name.keys()),len(pth_file))
assert len(model_name.keys())==len(pth_file)
# Out:
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet18_500_npclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet18_500_ptclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet50_500_npclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet50_500_ptclasses_imagenet.pth
# 4 4

# %%
def create_model(model_name, num_classes):
    name = model_name.lower()

    if "resnet18" in name:
        model = models.resnet18(weights=None)
        model.fc = nn.Linear(
        model.fc.in_features,
        num_classes
    )
    elif "resnet50" in name:
        model = models.resnet50(weights=None)
        model.fc = nn.Linear(
        model.fc.in_features,
        num_classes
    )
    elif "alexnet" in name:
        model = models.alexnet(weights=None)
    else:
        raise ValueError(
            f"Cannot determine architecture from: {model_name}"
        )

    return model

# %%
def load_checkpoint_model(checkpoint_path, model_name):
    checkpoint = torch.load(
        checkpoint_path,
        map_location=device,
        weights_only=False
    )

    classes = checkpoint["classes"]
    num_classes = checkpoint["num_classes"]

    model = create_model(
        model_name=model_name,
        num_classes=num_classes
    )

    model.load_state_dict(
        checkpoint["model_state_dict"]
    )

    model = model.to(device)
    model.eval()

    return model, classes

# %%
gradcam_transform = transforms.Compose([
    transforms.Resize(
        (320, 320),
        interpolation=InterpolationMode.BILINEAR,
        antialias=True
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
def generate_gradcam(model,image_tensor,target_layer,target_class=None):
    """Generate a Grad-CAM heatmap for one image."""
    if image_tensor.ndim != 4 or image_tensor.size(0) != 1:
        raise ValueError(
            "image_tensor must have shape [1, C, H, W]"
        )

    activations = {}
    gradients = {}

    def forward_hook(module, inputs, output):
        activations["value"] = output

        def save_gradient(gradient):
            gradients["value"] = gradient

        output.register_hook(save_gradient)

    hook_handle = target_layer.register_forward_hook(forward_hook)

    try:
        model.zero_grad(set_to_none=True)

        # Grad-CAM needs gradients, so do not use no_grad/inference_mode here.
        with torch.enable_grad():
            logits = model(image_tensor)
            predicted_class = int(logits.argmax(dim=1).item())

            if target_class is None:
                target_class = predicted_class
            else:
                target_class = int(target_class)

            if not 0 <= target_class < logits.size(1):
                raise ValueError(
                    f"target_class must be between 0 and {logits.size(1) - 1}"
                )

            logits[0, target_class].backward()

        feature_maps = activations["value"][0]
        feature_gradients = gradients["value"][0]

        # One importance weight for each feature-map channel.
        weights = feature_gradients.mean(
            dim=(1, 2),
            keepdim=True
        )

        heatmap = (weights * feature_maps).sum(dim=0)
        heatmap = torch.relu(heatmap)

        heatmap = heatmap - heatmap.min()
        heatmap_max = heatmap.max()

        if heatmap_max.item() > 0:
            heatmap = heatmap / heatmap_max

        probabilities = torch.softmax(logits.detach(), dim=1)

        return {
            "heatmap": heatmap.detach().cpu().numpy(),
            "predicted_class": predicted_class,
            "predicted_probability": probabilities[
                0, predicted_class
            ].item(),
            "target_class": target_class,
            "target_probability": probabilities[
                0, target_class
            ].item()
        }

    finally:
        hook_handle.remove()

# %%
def process_one_model(checkpoint_path,model_name,image_tensor):
    model, classes = load_checkpoint_model(
        checkpoint_path,
        model_name
    )

    result = generate_gradcam(
        model=model,
        image_tensor=image_tensor,
        target_layer=model.layer4[-1]
    )

    
    result["model_name"] = model_name
    result["checkpoint_path"] = str(checkpoint_path)
    result["predicted_name"] = classes[
        result["predicted_class"]
    ]

    del model

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return result

# %%
def one_img_prediction(img_path, output_dir):
    model_jobs = []

    
    image_path=Path(img_path)

    original_image = Image.open(image_path).convert("RGB")

    # Grad-CAM transform
    image_tensor = gradcam_transform(original_image)
    image_tensor = image_tensor.unsqueeze(0).to(device)



    for checkpoint_path in pth_file:
        filename = Path(checkpoint_path).name

        model_jobs.append({
            "path": checkpoint_path,
            "name": model_name[filename]
        })


    all_results = []

    for job in model_jobs:
        # print(f"\nProcessing: {job['name']}")

        result = process_one_model(
            checkpoint_path=job["path"],
            model_name=job["name"],
            image_tensor=image_tensor
        )

        all_results.append(result)

        print("Prediction:", result["predicted_name"])
        print(
            "Confidence:",
            f"{result['predicted_probability']:.2%}"
        )

    display_image = original_image.resize((320, 320))
    display_array = (
        np.asarray(display_image).astype(np.float32) / 255.0
    )

    fig, axes = plt.subplots(
        1,
        len(all_results),
        figsize=(6 * len(all_results), 6)
    )

    if len(all_results) == 1:
        axes = [axes]

    for ax, result in zip(axes, all_results):
        ax.imshow(display_array)
        ax.imshow(
            result["heatmap"],
            cmap="jet",
            alpha=0.4,
            extent=(0, 320, 320, 0)
        )

        ax.set_title(
            f"{result['model_name']}\n"
            f"{result['predicted_name'][:30]} "
            f"({result['predicted_probability']:.2%})"
        )
        ax.axis("off")
    
    fig.savefig(
        output_dir / image_path.name,
        dpi=300,
        bbox_inches="tight"
    )
    plt.tight_layout()
    plt.close(fig)
    plt.show()

# %%
Path.cwd()
output_dir = Path.cwd()/ "resnet_output"
output_dir.mkdir(parents=True, exist_ok=True)

rng = random.Random(0)

#grab folder name
class_folders = [
    folder for folder in DATA_ROOT.iterdir()
    if folder.is_dir()
]

#most error manual adding

if z > len(class_folders):
    raise ValueError("too much")

selected_classes = rng.sample(class_folders, z)

selected_classes.append(Path(r"D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos"))
selected_classes.append(Path(r"D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos"))
selected_classes.append(Path(r"D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos"))
selected_classes.append(Path(r"D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos"))
selected_classes.append(Path(r"D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos"))

i=0
for class_folder in selected_classes:
    image_files = [
        file for file in class_folder.iterdir()
        if file.suffix.lower() in {".jpg"}
    ]
    i+=1
    print(i,'/',z)
    print(class_folder)

    image_path = rng.choice(image_files)
    print(image_path)

    one_img_prediction(image_path,output_dir)
# Out:
# 1 / 10
# D:\dataset\sampled_500\val\08680_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Plantaginaceae_Plantago_ovata
# D:\dataset\sampled_500\val\08680_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Plantaginaceae_Plantago_ovata\d8999984-b161-4391-8211-1f69a7949e35.jpg
# Prediction: 03621_Animalia_Chordata_Aves_Galliformes_Odontophoridae_Callipepla_californica
# Confidence: 4.78%
# Prediction: 07518_Plantae_Tracheophyta_Magnoliopsida_Caryophyllales_Polygonaceae_Bistorta_bistortoides
# Confidence: 10.51%
# Prediction: 06335_Plantae_Tracheophyta_Liliopsida_Poales_Poaceae_Bothriochloa_laguroides
# Confidence: 67.47%
# Prediction: 07518_Plantae_Tracheophyta_Magnoliopsida_Caryophyllales_Polygonaceae_Bistorta_bistortoides
# Confidence: 7.72%
# 2 / 10
# D:\dataset\sampled_500\val\03687_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Iduna_caligata
# D:\dataset\sampled_500\val\03687_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Iduna_caligata\92ad9636-0a18-4dec-9525-b9826ddc6e3e.jpg
# Prediction: 06306_Plantae_Tracheophyta_Liliopsida_Poales_Juncaceae_Juncus_balticus
# Confidence: 35.16%
# Prediction: 04258_Animalia_Chordata_Aves_Passeriformes_Troglodytidae_Cistothorus_platensis
# Confidence: 19.37%
# Prediction: 06286_Plantae_Tracheophyta_Liliopsida_Poales_Cyperaceae_Eriophorum_angustifolium
# Confidence: 21.46%
# Prediction: 03981_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Luscinia_luscinia
# Confidence: 23.73%
# 3 / 10
# D:\dataset\sampled_500\val\07851_Plantae_Tracheophyta_Magnoliopsida_Ericales_Primulaceae_Lysimachia_clethroides
# D:\dataset\sampled_500\val\07851_Plantae_Tracheophyta_Magnoliopsida_Ericales_Primulaceae_Lysimachia_clethroides\89007fe1-66c7-471e-acbf-90ee0e59dfeb.jpg
# Prediction: 07851_Plantae_Tracheophyta_Magnoliopsida_Ericales_Primulaceae_Lysimachia_clethroides
# Confidence: 21.62%
# Prediction: 07851_Plantae_Tracheophyta_Magnoliopsida_Ericales_Primulaceae_Lysimachia_clethroides
# Confidence: 98.70%
# Prediction: 08144_Plantae_Tracheophyta_Magnoliopsida_Fagales_Betulaceae_Betula_alleghaniensis
# Confidence: 8.57%
# Prediction: 07851_Plantae_Tracheophyta_Magnoliopsida_Ericales_Primulaceae_Lysimachia_clethroides
# Confidence: 91.68%
# 4 / 10
# D:\dataset\sampled_500\val\09188_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Papaveraceae_Platystemon_californicus
# D:\dataset\sampled_500\val\09188_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Papaveraceae_Platystemon_californicus\878b4f75-4551-4e5b-bf21-c5805ae4028f.jpg
# Prediction: 05541_Fungi_Basidiomycota_Agaricomycetes_Agaricales_Mycenaceae_Roridomyces_austrororidus
# Confidence: 72.97%
# Prediction: 09188_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Papaveraceae_Platystemon_californicus
# Confidence: 42.12%
# Prediction: 05541_Fungi_Basidiomycota_Agaricomycetes_Agaricales_Mycenaceae_Roridomyces_austrororidus
# Confidence: 27.39%
# Prediction: 09188_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Papaveraceae_Platystemon_californicus
# Confidence: 80.41%
# 5 / 10
# D:\dataset\sampled_500\val\04247_Animalia_Chordata_Aves_Passeriformes_Thraupidae_Thraupis_sayaca
# D:\dataset\sampled_500\val\04247_Animalia_Chordata_Aves_Passeriformes_Thraupidae_Thraupis_sayaca\e5ab5382-838e-4ad2-a23a-e86266f1961b.jpg
# Prediction: 04500_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_funereus
# Confidence: 19.84%
# Prediction: 03934_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Philemon_corniculatus
# Confidence: 31.75%
# Prediction: 03304_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_nigricollis
# Confidence: 33.41%
# Prediction: 04247_Animalia_Chordata_Aves_Passeriformes_Thraupidae_Thraupis_sayaca
# Confidence: 42.14%
# 6 / 10
# D:\dataset\sampled_500\val\00357_Animalia_Arthropoda_Insecta_Coleoptera_Lucanidae_Dorcus_parallelipipedus
# D:\dataset\sampled_500\val\00357_Animalia_Arthropoda_Insecta_Coleoptera_Lucanidae_Dorcus_parallelipipedus\47d99c4d-e29e-4fe5-a5f9-3e08b989e30c.jpg
# Prediction: 00665_Animalia_Arthropoda_Insecta_Hemiptera_Rhyparochromidae_Rhyparochromus_vulgaris
# Confidence: 12.16%
# Prediction: 00357_Animalia_Arthropoda_Insecta_Coleoptera_Lucanidae_Dorcus_parallelipipedus
# Confidence: 87.44%
# Prediction: 00357_Animalia_Arthropoda_Insecta_Coleoptera_Lucanidae_Dorcus_parallelipipedus
# Confidence: 26.55%
# Prediction: 00357_Animalia_Arthropoda_Insecta_Coleoptera_Lucanidae_Dorcus_parallelipipedus
# Confidence: 88.64%
# 7 / 10
# D:\dataset\sampled_500\val\02448_Animalia_Arthropoda_Insecta_Odonata_Lestidae_Austrolestes_leda
# D:\dataset\sampled_500\val\02448_Animalia_Arthropoda_Insecta_Odonata_Lestidae_Austrolestes_leda\cac20754-cece-44a4-9d6c-02aacdc40355.jpg
# Prediction: 02450_Animalia_Arthropoda_Insecta_Odonata_Lestidae_Lestes_alacer
# Confidence: 42.47%
# Prediction: 02397_Animalia_Arthropoda_Insecta_Odonata_Coenagrionidae_Pseudagrion_microcephalum
# Confidence: 40.79%
# Prediction: 02450_Animalia_Arthropoda_Insecta_Odonata_Lestidae_Lestes_alacer
# Confidence: 48.79%
# Prediction: 02397_Animalia_Arthropoda_Insecta_Odonata_Coenagrionidae_Pseudagrion_microcephalum
# Confidence: 37.42%
# 8 / 10
# D:\dataset\sampled_500\val\09934_Plantae_Tracheophyta_Polypodiopsida_Polypodiales_Dennstaedtiaceae_Pteridium_pinetorum
# D:\dataset\sampled_500\val\09934_Plantae_Tracheophyta_Polypodiopsida_Polypodiales_Dennstaedtiaceae_Pteridium_pinetorum\53e554bd-347d-4959-a049-4c4e42177143.jpg
# Prediction: 09934_Plantae_Tracheophyta_Polypodiopsida_Polypodiales_Dennstaedtiaceae_Pteridium_pinetorum
# Confidence: 57.90%
# Prediction: 08549_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Oleaceae_Fraxinus_nigra
# Confidence: 12.04%
# Prediction: 09934_Plantae_Tracheophyta_Polypodiopsida_Polypodiales_Dennstaedtiaceae_Pteridium_pinetorum
# Confidence: 59.31%
# Prediction: 09934_Plantae_Tracheophyta_Polypodiopsida_Polypodiales_Dennstaedtiaceae_Pteridium_pinetorum
# Confidence: 92.67%
# 9 / 10
# D:\dataset\sampled_500\val\05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens
# D:\dataset\sampled_500\val\05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens\b6aa7e3a-98e9-4621-8880-f9a99aa9a96f.jpg
# Prediction: 02728_Animalia_Arthropoda_Malacostraca_Decapoda_Ocypodidae_Ocypode_quadrata
# Confidence: 29.86%
# Prediction: 05214_Animalia_Echinodermata_Echinoidea_Clypeasteroida_Dendrasteridae_Dendraster_excentricus
# Confidence: 14.07%
# Prediction: 08952_Plantae_Tracheophyta_Magnoliopsida_Malvales_Malvaceae_Horsfordia_newberryi
# Confidence: 17.62%
# Prediction: 05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens
# Confidence: 28.75%
# 10 / 10
# D:\dataset\sampled_500\val\04946_Animalia_Chordata_Reptilia_Squamata_Colubridae_Pantherophis_alleghaniensis
# D:\dataset\sampled_500\val\04946_Animalia_Chordata_Reptilia_Squamata_Colubridae_Pantherophis_alleghaniensis\4a7dd9f9-10fe-4cfa-8445-30bc04d6950d.jpg
# Prediction: 04202_Animalia_Chordata_Aves_Passeriformes_Sturnidae_Sturnus_vulgaris
# Confidence: 23.04%
# Prediction: 04946_Animalia_Chordata_Reptilia_Squamata_Colubridae_Pantherophis_alleghaniensis
# Confidence: 3.50%
# Prediction: 06468_Plantae_Tracheophyta_Lycopodiopsida_Lycopodiales_Lycopodiaceae_Lycopodium_clavatum
# Confidence: 12.26%
# Prediction: 04946_Animalia_Chordata_Reptilia_Squamata_Colubridae_Pantherophis_alleghaniensis
# Confidence: 88.94%
# 11 / 10
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos\329c174a-d4a8-4879-8c93-3d4f4f1fd740.jpg
# Prediction: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca
# Confidence: 35.61%
# Prediction: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# Confidence: 77.22%
# Prediction: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# Confidence: 18.26%
# Prediction: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# Confidence: 73.18%
# 12 / 10
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos\dcf11796-1b86-4820-b21f-b5b17c6c8a73.jpg
# Prediction: 03332_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_burrovianus
# Confidence: 44.13%
# Prediction: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# Confidence: 52.32%
# Prediction: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus
# Confidence: 17.94%
# Prediction: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca
# Confidence: 72.65%
# 13 / 10
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos\7c015678-65d7-493e-a677-98cb787814ec.jpg
# Prediction: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca
# Confidence: 22.16%
# Prediction: 04587_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_nebouxii
# Confidence: 38.95%
# Prediction: 04587_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_nebouxii
# Confidence: 42.07%
# Prediction: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# Confidence: 3.98%
# 14 / 10
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos\cd4112d9-0e3e-4573-ba7e-02413d7aff2e.jpg
# Prediction: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca
# Confidence: 34.14%
# Prediction: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca
# Confidence: 14.66%
# Prediction: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus
# Confidence: 27.48%
# Prediction: 03606_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_tinnunculus
# Confidence: 24.87%
# 15 / 10
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# D:\dataset\sampled_500\val\03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos\dcf11796-1b86-4820-b21f-b5b17c6c8a73.jpg
# Prediction: 03332_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_burrovianus
# Confidence: 44.13%
# Prediction: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos
# Confidence: 52.32%
# Prediction: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus
# Confidence: 17.94%
# Prediction: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca
# Confidence: 72.65%
