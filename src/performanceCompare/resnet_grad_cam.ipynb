# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from PIL import Image
from torchvision import models, transforms
from torchvision.transforms.functional import InterpolationMode

import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
DATA_ROOT = Path(r"/home/sergiocloudwork/dataset/sampled_500/val")
DATA_ROOT = Path(r"D:/dataset/sampled_500/val")
# number of image
z=10

# %%
loc = Path.cwd()
imgNetF = loc / "resNet_data"

pth_file=[]
# Find and read all JSON files recursively
for file_path in imgNetF.rglob("*.pth"):
    print(f"Found: {file_path}")
    pth_file.append(file_path)


model_name={"inat_resnet18_500_ptclasses_imagenet.pth":"ResNet18 pretrained model",
            "inat_resnet50_500_ptclasses_imagenet.pth":"ResNet50 pretrained model",
            "inat_resnet18_500_npclasses_imagenet.pth":"ResNet18 random start model",
            "inat_resnet50_500_npclasses_imagenet.pth":"ResNet50 random start model"
            }

assert len(model_name.keys())==len(pth_file)
# Out:
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet101_1000_ptclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet18_500_npclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet18_500_ptclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet50_500_npclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet50_500_ptclasses_imagenet.pth
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 17
#      13             "inat_resnet18_500_npclasses_imagenet.pth":"ResNet18 random start model",
#      14             "inat_resnet50_500_npclasses_imagenet.pth":"ResNet50 random start model"
#      15             }
#      16
# ---> 17 assert len(model_name.keys())==len(pth_file)
#
# AssertionError:

# %%
def create_model(model_name, num_classes):
    name = model_name.lower()

    if "resnet18" in name:
        model = models.resnet18(weights=None)
        model.fc = nn.Linear(
        model.fc.in_features,
        num_classes
    )
    elif "resnet50" in name:
        model = models.resnet50(weights=None)
        model.fc = nn.Linear(
        model.fc.in_features,
        num_classes
    )
    elif "alexnet" in name:
        model = models.alexnet(weights=None)
    else:
        raise ValueError(
            f"Cannot determine architecture from: {model_name}"
        )

    return model

# %%
def load_checkpoint_model(checkpoint_path, model_name):
    checkpoint = torch.load(
        checkpoint_path,
        map_location=device,
        weights_only=False
    )

    classes = checkpoint["classes"]
    num_classes = checkpoint["num_classes"]

    model = create_model(
        model_name=model_name,
        num_classes=num_classes
    )

    model.load_state_dict(
        checkpoint["model_state_dict"]
    )

    model = model.to(device)
    model.eval()

    return model, classes

# %%
gradcam_transform = transforms.Compose([
    transforms.Resize(
        (320, 320),
        interpolation=InterpolationMode.BILINEAR,
        antialias=True
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
def generate_gradcam(model,image_tensor,target_layer,target_class=None):
    """Generate a Grad-CAM heatmap for one image."""
    if image_tensor.ndim != 4 or image_tensor.size(0) != 1:
        raise ValueError(
            "image_tensor must have shape [1, C, H, W]"
        )

    activations = {}
    gradients = {}

    def forward_hook(module, inputs, output):
        activations["value"] = output

        def save_gradient(gradient):
            gradients["value"] = gradient

        output.register_hook(save_gradient)

    hook_handle = target_layer.register_forward_hook(forward_hook)

    try:
        model.zero_grad(set_to_none=True)

        # Grad-CAM needs gradients, so do not use no_grad/inference_mode here.
        with torch.enable_grad():
            logits = model(image_tensor)
            predicted_class = int(logits.argmax(dim=1).item())

            if target_class is None:
                target_class = predicted_class
            else:
                target_class = int(target_class)

            if not 0 <= target_class < logits.size(1):
                raise ValueError(
                    f"target_class must be between 0 and {logits.size(1) - 1}"
                )

            logits[0, target_class].backward()

        feature_maps = activations["value"][0]
        feature_gradients = gradients["value"][0]

        # One importance weight for each feature-map channel.
        weights = feature_gradients.mean(
            dim=(1, 2),
            keepdim=True
        )

        heatmap = (weights * feature_maps).sum(dim=0)
        heatmap = torch.relu(heatmap)

        heatmap = heatmap - heatmap.min()
        heatmap_max = heatmap.max()

        if heatmap_max.item() > 0:
            heatmap = heatmap / heatmap_max

        probabilities = torch.softmax(logits.detach(), dim=1)

        return {
            "heatmap": heatmap.detach().cpu().numpy(),
            "predicted_class": predicted_class,
            "predicted_probability": probabilities[
                0, predicted_class
            ].item(),
            "target_class": target_class,
            "target_probability": probabilities[
                0, target_class
            ].item()
        }

    finally:
        hook_handle.remove()

# %%
def process_one_model(checkpoint_path,model_name,image_tensor):
    model, classes = load_checkpoint_model(
        checkpoint_path,
        model_name
    )

    result = generate_gradcam(
        model=model,
        image_tensor=image_tensor,
        target_layer=model.layer4[-1]
    )

    
    result["model_name"] = model_name
    result["checkpoint_path"] = str(checkpoint_path)
    result["predicted_name"] = classes[
        result["predicted_class"]
    ]

    del model

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return result

# %%
def one_img_prediction(img_path, output_dir):
    model_jobs = []

    
    image_path=Path(img_path)

    original_image = Image.open(image_path).convert("RGB")

    # Grad-CAM transform
    image_tensor = gradcam_transform(original_image)
    image_tensor = image_tensor.unsqueeze(0).to(device)



    for checkpoint_path in pth_file:
        filename = Path(checkpoint_path).name

        model_jobs.append({
            "path": checkpoint_path,
            "name": model_name[filename]
        })


    all_results = []

    for job in model_jobs:
        # print(f"\nProcessing: {job['name']}")

        result = process_one_model(
            checkpoint_path=job["path"],
            model_name=job["name"],
            image_tensor=image_tensor
        )

        all_results.append(result)

        print("Prediction:", result["predicted_name"])
        print(
            "Confidence:",
            f"{result['predicted_probability']:.2%}"
        )

    display_image = original_image.resize((320, 320))
    display_array = (
        np.asarray(display_image).astype(np.float32) / 255.0
    )

    fig, axes = plt.subplots(
        1,
        len(all_results),
        figsize=(6 * len(all_results), 6)
    )

    if len(all_results) == 1:
        axes = [axes]

    for ax, result in zip(axes, all_results):
        ax.imshow(display_array)
        ax.imshow(
            result["heatmap"],
            cmap="jet",
            alpha=0.4,
            extent=(0, 320, 320, 0)
        )

        ax.set_title(
            f"{result['model_name']}\n"
            f"{result['predicted_name'][:30]} "
            f"({result['predicted_probability']:.2%})"
        )
        ax.axis("off")
    
    fig.savefig(
        output_dir / image_path.name,
        dpi=300,
        bbox_inches="tight"
    )
    plt.tight_layout()
    plt.close(fig)
    plt.show()

# %%
Path.cwd()
output_dir = Path.cwd()/ "resnet_output"
output_dir.mkdir(parents=True, exist_ok=True)

rng = random.Random()

#grab folder name
class_folders = [
    folder for folder in DATA_ROOT.iterdir()
    if folder.is_dir()
]

if z > len(class_folders):
    raise ValueError("too much")

selected_classes = rng.sample(class_folders, z)

selected_images = []

i=0
for class_folder in selected_classes:
    image_files = [
        file for file in class_folder.iterdir()
        if file.suffix.lower() in {".jpg"}
    ]
    i+=1
    print(i,'/',z)
    print(class_folder)

    image_path = rng.choice(image_files)
    print(image_path)

    one_img_prediction(image_path,output_dir)
# Out:
# 1 / 10
# D:\dataset\sampled_500\val\06193_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_albidum
# D:\dataset\sampled_500\val\06193_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_albidum\3def2807-662f-4e15-834a-79b826b23c30.jpg
# Prediction: 06193_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_albidum
# Confidence: 28.28%
# Prediction: 06193_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_albidum
# Confidence: 52.96%
# Prediction: 06193_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_albidum
# Confidence: 45.65%
# Prediction: 06193_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_albidum
# Confidence: 69.52%
# 2 / 10
# D:\dataset\sampled_500\val\08462_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Mentha_aquatica
# D:\dataset\sampled_500\val\08462_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Mentha_aquatica\78eb0686-a540-499b-ba04-cd3b24df645a.jpg
# Prediction: 08462_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Mentha_aquatica
# Confidence: 12.18%
# Prediction: 08462_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Mentha_aquatica
# Confidence: 23.53%
# Prediction: 08462_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Mentha_aquatica
# Confidence: 56.63%
# Prediction: 08462_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Mentha_aquatica
# Confidence: 95.15%
# 3 / 10
# D:\dataset\sampled_500\val\05574_Fungi_Basidiomycota_Agaricomycetes_Agaricales_Schizophyllaceae_Schizophyllum_commune
# D:\dataset\sampled_500\val\05574_Fungi_Basidiomycota_Agaricomycetes_Agaricales_Schizophyllaceae_Schizophyllum_commune\f7ea0da9-ac7b-4b8b-8633-46e022afbaf1.jpg
# Prediction: 01251_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Lomaspilis_marginata
# Confidence: 28.62%
# Prediction: 03981_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Luscinia_luscinia
# Confidence: 1.21%
# Prediction: 07849_Plantae_Tracheophyta_Magnoliopsida_Ericales_Primulaceae_Lysimachia_borealis
# Confidence: 28.03%
# Prediction: 05574_Fungi_Basidiomycota_Agaricomycetes_Agaricales_Schizophyllaceae_Schizophyllum_commune
# Confidence: 22.43%
# 4 / 10
# D:\dataset\sampled_500\val\06736_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Cyclachaena_xanthiifolia
# D:\dataset\sampled_500\val\06736_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Cyclachaena_xanthiifolia\0203d72e-533f-4c78-91be-8529fe434b85.jpg
# Prediction: 06736_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Cyclachaena_xanthiifolia
# Confidence: 47.80%
# Prediction: 06736_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Cyclachaena_xanthiifolia
# Confidence: 44.12%
# Prediction: 07313_Plantae_Tracheophyta_Magnoliopsida_Caryophyllales_Amaranthaceae_Amaranthus_palmeri
# Confidence: 12.88%
# Prediction: 06736_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Cyclachaena_xanthiifolia
# Confidence: 98.13%
# 5 / 10
# D:\dataset\sampled_500\val\03584_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Crotophaga_ani
# D:\dataset\sampled_500\val\03584_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Crotophaga_ani\1afc63a7-2771-4d65-8398-9821657879b7.jpg
# Prediction: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus
# Confidence: 14.45%
# Prediction: 03934_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Philemon_corniculatus
# Confidence: 3.43%
# Prediction: 03934_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Philemon_corniculatus
# Confidence: 9.71%
# Prediction: 03584_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Crotophaga_ani
# Confidence: 33.33%
# 6 / 10
# D:\dataset\sampled_500\val\02554_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Potamarcha_congener
# D:\dataset\sampled_500\val\02554_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Potamarcha_congener\4d12b4ba-335f-4481-8c8a-54ace71b2ade.jpg
# Prediction: 02530_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Orthemis_ferruginea
# Confidence: 17.91%
# Prediction: 02554_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Potamarcha_congener
# Confidence: 6.46%
# Prediction: 02530_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Orthemis_ferruginea
# Confidence: 22.62%
# Prediction: 02530_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Orthemis_ferruginea
# Confidence: 54.11%
# 7 / 10
# D:\dataset\sampled_500\val\08116_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Vicia_ludoviciana
# D:\dataset\sampled_500\val\08116_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Vicia_ludoviciana\d76f0224-1e5f-4b26-a892-3cac6fa88081.jpg
# Prediction: 08116_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Vicia_ludoviciana
# Confidence: 25.86%
# Prediction: 08116_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Vicia_ludoviciana
# Confidence: 26.36%
# Prediction: 08086_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Trifolium_arvense
# Confidence: 10.95%
# Prediction: 08116_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Vicia_ludoviciana
# Confidence: 64.67%
# 8 / 10
# D:\dataset\sampled_500\val\02431_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Gomphus_vulgatissimus
# D:\dataset\sampled_500\val\02431_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Gomphus_vulgatissimus\804c47c4-0506-4195-93cd-bbc6d50cc7a8.jpg
# Prediction: 02431_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Gomphus_vulgatissimus
# Confidence: 77.92%
# Prediction: 02431_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Gomphus_vulgatissimus
# Confidence: 15.06%
# Prediction: 02431_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Gomphus_vulgatissimus
# Confidence: 88.99%
# Prediction: 02431_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Gomphus_vulgatissimus
# Confidence: 40.52%
# 9 / 10
# D:\dataset\sampled_500\val\09588_Plantae_Tracheophyta_Magnoliopsida_Sapindales_Sapindaceae_Cardiospermum_halicacabum
# D:\dataset\sampled_500\val\09588_Plantae_Tracheophyta_Magnoliopsida_Sapindales_Sapindaceae_Cardiospermum_halicacabum\48fd3dd7-e27f-4b02-a9ca-fff939f066f3.jpg
# Prediction: 09148_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Berberidaceae_Berberis_trifoliolata
# Confidence: 21.54%
# Prediction: 08016_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Macroptilium_gibbosifolium
# Confidence: 1.63%
# Prediction: 07134_Plantae_Tracheophyta_Magnoliopsida_Boraginales_Boraginaceae_Buglossoides_arvensis
# Confidence: 15.91%
# Prediction: 08016_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Macroptilium_gibbosifolium
# Confidence: 15.98%
# 10 / 10
# D:\dataset\sampled_500\val\06203_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_ovatum
# D:\dataset\sampled_500\val\06203_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_ovatum\a2804bcf-543f-490e-ae2b-bc79467119e3.jpg
# Prediction: 06203_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_ovatum
# Confidence: 61.96%
# Prediction: 06203_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_ovatum
# Confidence: 27.59%
# Prediction: 06203_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_ovatum
# Confidence: 36.47%
# Prediction: 06203_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_ovatum
# Confidence: 44.84%
