# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from PIL import Image
from torchvision import models, transforms
from torchvision.transforms.functional import InterpolationMode

import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
DATA_ROOT = Path(r"/home/sergiocloudwork/dataset/sampled_500/val")
DATA_ROOT = Path(r"D:/dataset/sampled_500/val")
# number of image
z=10

# %%
loc = Path.cwd()
imgNetF = loc / "resNet_data"

pth_file=[]
# Find and read all JSON files recursively
for file_path in imgNetF.rglob("*.pth"):
    print(f"Found: {file_path}")
    pth_file.append(file_path)


model_name={"inat_resnet18_500_ptclasses_imagenet.pth":"ResNet18 pretrained model",
            "inat_resnet50_500_ptclasses_imagenet.pth":"ResNet50 pretrained model",
            "inat_resnet18_500_npclasses_imagenet.pth":"ResNet18 random start model",
            "inat_resnet50_500_npclasses_imagenet.pth":"ResNet50 random start model"
            }

assert len(model_name.keys())==len(pth_file)
# Out:
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet18_500_npclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet18_500_ptclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet50_500_npclasses_imagenet.pth
# Found: c:\Users\mark\OneDrive\文档\GitHub\COMP9517GROUP_SUBJECT\src\performanceCompare\resNet_data\inat_resnet50_500_ptclasses_imagenet.pth

# %%
def create_model(model_name, num_classes):
    name = model_name.lower()

    if "resnet18" in name:
        model = models.resnet18(weights=None)
        model.fc = nn.Linear(
        model.fc.in_features,
        num_classes
    )
    elif "resnet50" in name:
        model = models.resnet50(weights=None)
        model.fc = nn.Linear(
        model.fc.in_features,
        num_classes
    )
    elif "alexnet" in name:
        model = models.alexnet(weights=None)
    else:
        raise ValueError(
            f"Cannot determine architecture from: {model_name}"
        )

    return model

# %%
def load_checkpoint_model(checkpoint_path, model_name):
    checkpoint = torch.load(
        checkpoint_path,
        map_location=device,
        weights_only=False
    )

    classes = checkpoint["classes"]
    num_classes = checkpoint["num_classes"]

    model = create_model(
        model_name=model_name,
        num_classes=num_classes
    )

    model.load_state_dict(
        checkpoint["model_state_dict"]
    )

    model = model.to(device)
    model.eval()

    return model, classes

# %%
gradcam_transform = transforms.Compose([
    transforms.Resize(
        (320, 320),
        interpolation=InterpolationMode.BILINEAR,
        antialias=True
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
def generate_gradcam(model,image_tensor,target_layer,target_class=None):
    """Generate a Grad-CAM heatmap for one image."""
    if image_tensor.ndim != 4 or image_tensor.size(0) != 1:
        raise ValueError(
            "image_tensor must have shape [1, C, H, W]"
        )

    activations = {}
    gradients = {}

    def forward_hook(module, inputs, output):
        activations["value"] = output

        def save_gradient(gradient):
            gradients["value"] = gradient

        output.register_hook(save_gradient)

    hook_handle = target_layer.register_forward_hook(forward_hook)

    try:
        model.zero_grad(set_to_none=True)

        # Grad-CAM needs gradients, so do not use no_grad/inference_mode here.
        with torch.enable_grad():
            logits = model(image_tensor)
            predicted_class = int(logits.argmax(dim=1).item())

            if target_class is None:
                target_class = predicted_class
            else:
                target_class = int(target_class)

            if not 0 <= target_class < logits.size(1):
                raise ValueError(
                    f"target_class must be between 0 and {logits.size(1) - 1}"
                )

            logits[0, target_class].backward()

        feature_maps = activations["value"][0]
        feature_gradients = gradients["value"][0]

        # One importance weight for each feature-map channel.
        weights = feature_gradients.mean(
            dim=(1, 2),
            keepdim=True
        )

        heatmap = (weights * feature_maps).sum(dim=0)
        heatmap = torch.relu(heatmap)

        heatmap = heatmap - heatmap.min()
        heatmap_max = heatmap.max()

        if heatmap_max.item() > 0:
            heatmap = heatmap / heatmap_max

        probabilities = torch.softmax(logits.detach(), dim=1)

        return {
            "heatmap": heatmap.detach().cpu().numpy(),
            "predicted_class": predicted_class,
            "predicted_probability": probabilities[
                0, predicted_class
            ].item(),
            "target_class": target_class,
            "target_probability": probabilities[
                0, target_class
            ].item()
        }

    finally:
        hook_handle.remove()

# %%
def process_one_model(checkpoint_path,model_name,image_tensor):
    model, classes = load_checkpoint_model(
        checkpoint_path,
        model_name
    )

    result = generate_gradcam(
        model=model,
        image_tensor=image_tensor,
        target_layer=model.layer4[-1]
    )

    
    result["model_name"] = model_name
    result["checkpoint_path"] = str(checkpoint_path)
    result["predicted_name"] = classes[
        result["predicted_class"]
    ]

    del model

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return result

# %%
def one_img_prediction(img_path, output_dir):
    model_jobs = []

    
    image_path=Path(img_path)

    original_image = Image.open(image_path).convert("RGB")

    # # 使用之前定义的 Grad-CAM transform
    image_tensor = gradcam_transform(original_image)
    image_tensor = image_tensor.unsqueeze(0).to(device)



    for checkpoint_path in pth_file:
        filename = Path(checkpoint_path).name

        model_jobs.append({
            "path": checkpoint_path,
            "name": model_name[filename]
        })


    all_results = []

    for job in model_jobs:
        # print(f"\nProcessing: {job['name']}")

        result = process_one_model(
            checkpoint_path=job["path"],
            model_name=job["name"],
            image_tensor=image_tensor
        )

        all_results.append(result)

        print("Prediction:", result["predicted_name"])
        print(
            "Confidence:",
            f"{result['predicted_probability']:.2%}"
        )

    display_image = original_image.resize((320, 320))
    display_array = (
        np.asarray(display_image).astype(np.float32) / 255.0
    )

    fig, axes = plt.subplots(
        1,
        len(all_results),
        figsize=(6 * len(all_results), 6)
    )

    if len(all_results) == 1:
        axes = [axes]

    for ax, result in zip(axes, all_results):
        ax.imshow(display_array)
        ax.imshow(
            result["heatmap"],
            cmap="jet",
            alpha=0.4,
            extent=(0, 320, 320, 0)
        )

        ax.set_title(
            f"{result['model_name']}\n"
            f"{result['predicted_name'][:30]} "
            f"({result['predicted_probability']:.2%})"
        )
        ax.axis("off")
    
    fig.savefig(
        output_dir / image_path.name,
        dpi=300,
        bbox_inches="tight"
    )
    plt.tight_layout()
    plt.close(fig)
    plt.show()

# %%
Path.cwd()
output_dir = Path.cwd()/ "resnet_output"
output_dir.mkdir(parents=True, exist_ok=True)

rng = random.Random()

#grab folder name
class_folders = [
    folder for folder in DATA_ROOT.iterdir()
    if folder.is_dir()
]

if z > len(class_folders):
    raise ValueError("too much")

selected_classes = rng.sample(class_folders, z)

selected_images = []

i=0
for class_folder in selected_classes:
    image_files = [
        file for file in class_folder.iterdir()
        if file.suffix.lower() in {".jpg"}
    ]
    i+=1
    print(i,'/',z)
    print(class_folder)

    image_path = rng.choice(image_files)
    print(image_path)

    one_img_prediction(image_path,output_dir)
# Out:
# 1 / 10
# D:\dataset\sampled_500\val\09807_Plantae_Tracheophyta_Pinopsida_Pinales_Pinaceae_Picea_abies
# D:\dataset\sampled_500\val\09807_Plantae_Tracheophyta_Pinopsida_Pinales_Pinaceae_Picea_abies\4c707714-56e1-4ae2-90b3-3a60d9ea6bba.jpg
# Prediction: 00241_Animalia_Arthropoda_Insecta_Coleoptera_Cerambycidae_Plectrodera_scalator
# Confidence: 40.14%
# Prediction: 08085_Plantae_Tracheophyta_Magnoliopsida_Fabales_Fabaceae_Trifolium_angustifolium
# Confidence: 3.22%
# Prediction: 09807_Plantae_Tracheophyta_Pinopsida_Pinales_Pinaceae_Picea_abies
# Confidence: 26.61%
# Prediction: 09807_Plantae_Tracheophyta_Pinopsida_Pinales_Pinaceae_Picea_abies
# Confidence: 36.25%
# 2 / 10
# D:\dataset\sampled_500\val\05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens
# D:\dataset\sampled_500\val\05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens\d755d83e-11db-4bd6-badc-ec40498986b7.jpg
# Prediction: 02728_Animalia_Arthropoda_Malacostraca_Decapoda_Ocypodidae_Ocypode_quadrata
# Confidence: 31.06%
# Prediction: 05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens
# Confidence: 43.60%
# Prediction: 02728_Animalia_Arthropoda_Malacostraca_Decapoda_Ocypodidae_Ocypode_quadrata
# Confidence: 68.73%
# Prediction: 05194_Animalia_Cnidaria_Scyphozoa_Semaeostomeae_Pelagiidae_Chrysaora_fuscescens
# Confidence: 38.87%
# 3 / 10
# D:\dataset\sampled_500\val\03996_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_caprata
# D:\dataset\sampled_500\val\03996_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_caprata\f48461a2-900c-4978-8167-bb1a57c8aab5.jpg
# Prediction: 03144_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_cyaneus
# Confidence: 13.22%
# Prediction: 03621_Animalia_Chordata_Aves_Galliformes_Odontophoridae_Callipepla_californica
# Confidence: 11.20%
# Prediction: 03996_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_caprata
# Confidence: 16.55%
# Prediction: 03606_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_tinnunculus
# Confidence: 53.58%
# 4 / 10
# D:\dataset\sampled_500\val\07808_Plantae_Tracheophyta_Magnoliopsida_Ericales_Polemoniaceae_Eriastrum_densifolium
# D:\dataset\sampled_500\val\07808_Plantae_Tracheophyta_Magnoliopsida_Ericales_Polemoniaceae_Eriastrum_densifolium\7b693f6b-57d7-41f1-896c-5cf27a607294.jpg
# Prediction: 05885_Plantae_Tracheophyta_Liliopsida_Asparagales_Asparagaceae_Brodiaea_terrestris
# Confidence: 9.38%
# Prediction: 07808_Plantae_Tracheophyta_Magnoliopsida_Ericales_Polemoniaceae_Eriastrum_densifolium
# Confidence: 22.94%
# Prediction: 08486_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Lamiaceae_Salvia_columbariae
# Confidence: 11.31%
# Prediction: 05885_Plantae_Tracheophyta_Liliopsida_Asparagales_Asparagaceae_Brodiaea_terrestris
# Confidence: 25.78%
# 5 / 10
# D:\dataset\sampled_500\val\03618_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_purpurascens
# D:\dataset\sampled_500\val\03618_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_purpurascens\4cb729b3-d900-48e0-b131-ac9d9c5d75c6.jpg
# Prediction: 03618_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_purpurascens
# Confidence: 62.40%
# Prediction: 03618_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_purpurascens
# Confidence: 77.36%
# Prediction: 04446_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_martius
# Confidence: 26.87%
# Prediction: 03618_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_purpurascens
# Confidence: 91.40%
# 6 / 10
# D:\dataset\sampled_500\val\02438_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Phanogomphus_spicatus
# D:\dataset\sampled_500\val\02438_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Phanogomphus_spicatus\df1cd08c-d0e7-43c7-b7e0-075b351eb2e6.jpg
# Prediction: 02438_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Phanogomphus_spicatus
# Confidence: 74.04%
# Prediction: 02438_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Phanogomphus_spicatus
# Confidence: 4.88%
# Prediction: 00203_Animalia_Arthropoda_Insecta_Coleoptera_Carabidae_Cicindela_hirticollis
# Confidence: 41.98%
# Prediction: 02438_Animalia_Arthropoda_Insecta_Odonata_Gomphidae_Phanogomphus_spicatus
# Confidence: 41.54%
# 7 / 10
# D:\dataset\sampled_500\val\00145_Animalia_Arthropoda_Arachnida_Opiliones_Phalangiidae_Phalangium_opilio
# D:\dataset\sampled_500\val\00145_Animalia_Arthropoda_Arachnida_Opiliones_Phalangiidae_Phalangium_opilio\5abc769f-e088-46fd-a2cb-3105ce5ae1a0.jpg
# Prediction: 01318_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Traminda_aventiaria
# Confidence: 14.01%
# Prediction: 00230_Animalia_Arthropoda_Insecta_Coleoptera_Cerambycidae_Knulliana_cincta
# Confidence: 14.36%
# Prediction: 00230_Animalia_Arthropoda_Insecta_Coleoptera_Cerambycidae_Knulliana_cincta
# Confidence: 36.26%
# Prediction: 00145_Animalia_Arthropoda_Arachnida_Opiliones_Phalangiidae_Phalangium_opilio
# Confidence: 90.87%
# 8 / 10
# D:\dataset\sampled_500\val\05796_Plantae_Tracheophyta_Liliopsida_Alismatales_Araceae_Calla_palustris
# D:\dataset\sampled_500\val\05796_Plantae_Tracheophyta_Liliopsida_Alismatales_Araceae_Calla_palustris\93ffd24f-e462-4c33-9c84-61f55153ae71.jpg
# Prediction: 05796_Plantae_Tracheophyta_Liliopsida_Alismatales_Araceae_Calla_palustris
# Confidence: 43.59%
# Prediction: 05796_Plantae_Tracheophyta_Liliopsida_Alismatales_Araceae_Calla_palustris
# Confidence: 16.81%
# Prediction: 05796_Plantae_Tracheophyta_Liliopsida_Alismatales_Araceae_Calla_palustris
# Confidence: 19.74%
# Prediction: 05796_Plantae_Tracheophyta_Liliopsida_Alismatales_Araceae_Calla_palustris
# Confidence: 33.61%
# 9 / 10
# D:\dataset\sampled_500\val\03655_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_americana
# D:\dataset\sampled_500\val\03655_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_americana\cbcb7911-c691-4f3b-84a2-b7cc1addcc84.jpg
# Prediction: 09772_Plantae_Tracheophyta_Magnoliopsida_Zygophyllales_Zygophyllaceae_Larrea_tridentata
# Confidence: 16.89%
# Prediction: 03498_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_totanus
# Confidence: 1.39%
# Prediction: 09832_Plantae_Tracheophyta_Pinopsida_Pinales_Pinaceae_Pinus_pinea
# Confidence: 8.39%
# Prediction: 03655_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_americana
# Confidence: 14.36%
# 10 / 10
# D:\dataset\sampled_500\val\05313_Animalia_Mollusca_Gastropoda_Nudibranchia_Facelinidae_Pteraeolidia_ianthina
# D:\dataset\sampled_500\val\05313_Animalia_Mollusca_Gastropoda_Nudibranchia_Facelinidae_Pteraeolidia_ianthina\59b1a15a-d4bc-4bed-a615-be2fd73d1d88.jpg
# Prediction: 05313_Animalia_Mollusca_Gastropoda_Nudibranchia_Facelinidae_Pteraeolidia_ianthina
# Confidence: 52.78%
# Prediction: 05313_Animalia_Mollusca_Gastropoda_Nudibranchia_Facelinidae_Pteraeolidia_ianthina
# Confidence: 64.54%
# Prediction: 05313_Animalia_Mollusca_Gastropoda_Nudibranchia_Facelinidae_Pteraeolidia_ianthina
# Confidence: 67.80%
# Prediction: 05313_Animalia_Mollusca_Gastropoda_Nudibranchia_Facelinidae_Pteraeolidia_ianthina
# Confidence: 77.35%
