# %%
import sys
import platform
import os
from pathlib import Path

import numpy as np
import torch
import torchvision
import cv2
import sklearn

try:
    import psutil
except ImportError:
    psutil = None


print("=== Software versions ===")
print("Python:", sys.version.replace("\n", " "))
print("PyTorch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("OpenCV:", cv2.__version__)
print("scikit-learn:", sklearn.__version__)
print("NumPy:", np.__version__)

print("\n=== Operating system ===")
print("Platform:", platform.platform())
print("System:", platform.system())
print("Release:", platform.release())

print("\n=== CPU and memory ===")
print("CPU:", platform.processor())

if psutil is not None:
    print("Physical CPU cores:", psutil.cpu_count(logical=False))
    print("Logical CPU cores:", psutil.cpu_count(logical=True))
    print(
        "System memory:",
        f"{psutil.virtual_memory().total / 1024**3:.2f} GB"
    )

print("\n=== GPU ===")
print("CUDA available:", torch.cuda.is_available())
print("CUDA version used by PyTorch:", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        properties = torch.cuda.get_device_properties(i)

        print(f"GPU {i}:", properties.name)
        print(
            f"GPU {i} memory:",
            f"{properties.total_memory / 1024**3:.2f} GB"
        )

print("\n=== Reproducibility settings ===")
print("PyTorch initial seed:", torch.initial_seed())
print(
    "Deterministic algorithms:",
    torch.are_deterministic_algorithms_enabled()
)
print(
    "cuDNN deterministic:",
    torch.backends.cudnn.deterministic
)
print(
    "cuDNN benchmark:",
    torch.backends.cudnn.benchmark
)
print(
    "CUBLAS_WORKSPACE_CONFIG:",
    os.environ.get("CUBLAS_WORKSPACE_CONFIG", "Not set")
)

print("\n=== Project location ===")
print("Current working directory:", Path.cwd())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 import os
#       4 from pathlib import Path
#       5
#       6 import numpy as np
# ----> 7 import torch
#       8 import torchvision
#       9 import cv2
#      10 import sklearn
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\__init__.py:2254
#    2247 from torch._compile import _disable_dynamo  # usort: skip
#    2249 ################################################################################
#    2250 # Import interface functions defined in Python
#    2251 ################################################################################
#    2252
#    2253 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2254 from torch import _VF as _VF, functional as functional  # usort: skip
#    2255 from torch.functional import *  # usort: skip # noqa: F403
#    2257 ################################################################################
#    2258 # Remove unnecessary members
#    2259 ################################################################################
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\functional.py:8
#       5 from typing import Any, TYPE_CHECKING
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#      10 from torch._C import _add_docstr
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\__init__.py:8
#       1 # mypy: allow-untyped-defs
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)     16     utils as utils,
#      17 )
#      18 from torch.nn.parallel import DataParallel as DataParallel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\__init__.py:1
# ----> 1 from .module import Module  # usort: skip
#       2 from .linear import Bilinear, Identity, LazyLinear, Linear  # usort: skip
#       3 from .activation import (
#       4     CELU,
#       5     ELU,
#    (...)     32     Threshold,
#      33 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:17
#      15 from torch._prims_common import DeviceLikeType
#      16 from torch.nn.parameter import Buffer, Parameter
# ---> 17 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
#      18 from torch.utils.hooks import BackwardHook, RemovableHandle
#      21 __all__ = [
#      22     "register_module_forward_pre_hook",
#      23     "register_module_forward_hook",
#    (...)     30     "Module",
#      31 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_python_dispatch.py:13
#      10 from typing_extensions import TypeIs
#      12 import torch
# ---> 13 import torchgen
#      14 import torchgen.model
#      15 from torch._C import (
#      16     _get_dispatch_stack_at,
#      17     _len_torch_dispatch_stack,
#    (...)     20     DispatchKey,
#      21 )
#
# ModuleNotFoundError: No module named 'torchgen'

# %%
# !pip cache purge
# Out:
# Files removed: 1 (1.8 kB)
# Directories removed: 0

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in C:\Users\mark\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.13.0+cu126)
# Requirement already satisfied: torchvision in C:\Users\mark\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.28.0+cu126)
# Requirement already satisfied: numpy in C:\Users\mark\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torchvision) (2.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\mark\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torchvision) (12.3.0)
